# %%
#import python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../')
#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#database connection
from script import db_connection
#sqlalchemy
alchemyConn=db_connection.db_connection_sqlalchemy()
#pycopg2
pgconn=db_connection.db_connection_psycopg()
print(alchemyConn)
print(pgconn)
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/telecom)
# <connection object at 0x0000021EF32C1E00; dsn: 'user=postgres password=xxx dbname=telecom host=localhost port=5432', closed: 0>

# %%
# get all data from postgresql using sqlalchemy
dfa = db_connection.db_read_table_sqlalchemy(alchemyConn, 'xdr_data')
dfa.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
# get all data from postgresql using sqlalchemy
dfg = db_connection.db_read_table_psycopg(pgconn, 'xdr_data')
dfg.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
#the data type and information about data
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
#  10  Avg RTT DL (ms)                           122172 non-null  float64
#  11  Avg RTT UL (ms)                           122189 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   150000 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   150000 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               61855 non-null   float64
#  15  TCP UL Retrans. Vol (Bytes)               53352 non-null   float64
#  16  DL TP < 50 Kbps (%)                       149247 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            149247 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             149247 non-null  float64
#  19  DL TP > 1 Mbps (%)                        149247 non-null  float64
#  20  UL TP < 10 Kbps (%)                       149209 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             149209 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            149209 non-null  float64
#  23  UL TP > 300 Kbps (%)                      149209 non-null  float64
#  24  HTTP DL (Bytes)                           68527 non-null   float64
#  25  HTTP UL (Bytes)                           68191 non-null   float64
#  26  Activity Duration DL (ms)                 150000 non-null  float64
#  27  Activity Duration UL (ms)                 150000 non-null  float64
#  28  Dur. (ms).1                               150000 non-null  float64
#  29  Handset Manufacturer                      149429 non-null  object
#  30  Handset Type                              149429 non-null  object
#  31  Nb of sec with 125000B < Vol DL           52463 non-null   float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     57107 non-null   float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  56415 non-null   float64
#  34  Nb of sec with 37500B < Vol UL            19747 non-null   float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    61684 non-null   float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    38158 non-null   float64
#  37  Nb of sec with Vol DL < 6250B             149246 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             149208 non-null  float64
#  39  Social Media DL (Bytes)                   150001 non-null  float64
#  40  Social Media UL (Bytes)                   150001 non-null  float64
#  41  Google DL (Bytes)                         150001 non-null  float64
#  42  Google UL (Bytes)                         150001 non-null  float64
#  43  Email DL (Bytes)                          150001 non-null  float64
#  44  Email UL (Bytes)                          150001 non-null  float64
#  45  Youtube DL (Bytes)                        150001 non-null  float64
#  46  Youtube UL (Bytes)                        150001 non-null  float64
#  47  Netflix DL (Bytes)                        150001 non-null  float64
#  48  Netflix UL (Bytes)                        150001 non-null  float64
#  49  Gaming DL (Bytes)                         150001 non-null  float64
#  50  Gaming UL (Bytes)                         150001 non-null  float64
#  51  Other DL (Bytes)                          150001 non-null  float64
#  52  Other UL (Bytes)                          150001 non-null  float64
#  53  Total UL (Bytes)                          150000 non-null  float64
#  54  Total DL (Bytes)                          150000 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 62.9+ MB

# %%
#Check for Duplication
dfa.nunique()
dfa.Start.unique()
dfa.Start.nunique()
# Out:
# 9997

# %%
#Missing Values Calculation
dfa.isnull().sum()
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# 250 Kbps < DL TP < 1 Mbps (%)                  754
# DL TP > 1 Mbps (%)                             754
# UL TP < 10 Kbps (%)                            792
# 10 Kbps < UL TP < 50 Kbps (%)                  792
# 50 Kbps < UL TP < 300 Kbps (%)                 792
# UL TP > 300 Kbps (%)                           792
# HTTP DL (Bytes)                              81474
# HTTP UL (Bytes)                              81810
# Activity Duration DL (ms)                        1
# Activity Duration UL (ms)                        1
# Dur. (ms).1                                      1
# Handset Manufacturer                           572
# Handset Type                                   572
# Nb of sec with 125000B < Vol DL              97538
# Nb of sec with 1250B < Vol UL < 6250B        92894
# Nb of sec with 31250B < Vol DL < 125000B     93586
# Nb of sec with 37500B < Vol UL              130254
# Nb of sec with 6250B < Vol DL < 31250B       88317
# Nb of sec with 6250B < Vol UL < 37500B      111843
# Nb of sec with Vol DL < 6250B                  755
# Nb of sec with Vol UL < 1250B                  793
# Social Media DL (Bytes)                          0
# Social Media UL (Bytes)                          0
# Google DL (Bytes)                                0
# Google UL (Bytes)                                0
# Email DL (Bytes)                                 0
# Email UL (Bytes)                                 0
# Youtube DL (Bytes)                               0
# Youtube UL (Bytes)                               0
# Netflix DL (Bytes)                               0
# Netflix UL (Bytes)                               0
# Gaming DL (Bytes)                                0
# Gaming UL (Bytes)                                0
# Other DL (Bytes)                                 0
# Other UL (Bytes)                                 0
# Total UL (Bytes)                                 1
# Total DL (Bytes)                                 1
# dtype: int64

# %%
#percentage of missing values 
(dfa.isnull().sum()/(len(dfa)))*100
# Out:
# Bearer Id                                    0.660662
# Start                                        0.000667
# Start ms                                     0.000667
# End                                          0.000667
# End ms                                       0.000667
# Dur. (ms)                                    0.000667
# IMSI                                         0.379997
# MSISDN/Number                                0.710662
# IMEI                                         0.381331
# Last Location Name                           0.768662
# Avg RTT DL (ms)                             18.552543
# Avg RTT UL (ms)                             18.541210
# Avg Bearer TP DL (kbps)                      0.000667
# Avg Bearer TP UL (kbps)                      0.000667
# TCP DL Retrans. Vol (Bytes)                 58.763608
# TCP UL Retrans. Vol (Bytes)                 64.432237
# DL TP < 50 Kbps (%)                          0.502663
# 50 Kbps < DL TP < 250 Kbps (%)               0.502663
# 250 Kbps < DL TP < 1 Mbps (%)                0.502663
# DL TP > 1 Mbps (%)                           0.502663
# UL TP < 10 Kbps (%)                          0.527996
# 10 Kbps < UL TP < 50 Kbps (%)                0.527996
# 50 Kbps < UL TP < 300 Kbps (%)               0.527996
# UL TP > 300 Kbps (%)                         0.527996
# HTTP DL (Bytes)                             54.315638
# HTTP UL (Bytes)                             54.539636
# Activity Duration DL (ms)                    0.000667
# Activity Duration UL (ms)                    0.000667
# Dur. (ms).1                                  0.000667
# Handset Manufacturer                         0.381331
# Handset Type                                 0.381331
# Nb of sec with 125000B < Vol DL             65.024900
# Nb of sec with 1250B < Vol UL < 6250B       61.928920
# Nb of sec with 31250B < Vol DL < 125000B    62.390251
# Nb of sec with 37500B < Vol UL              86.835421
# Nb of sec with 6250B < Vol DL < 31250B      58.877607
# Nb of sec with 6250B < Vol UL < 37500B      74.561503
# Nb of sec with Vol DL < 6250B                0.503330
# Nb of sec with Vol UL < 1250B                0.528663
# Social Media DL (Bytes)                      0.000000
# Social Media UL (Bytes)                      0.000000
# Google DL (Bytes)                            0.000000
# Google UL (Bytes)                            0.000000
# Email DL (Bytes)                             0.000000
# Email UL (Bytes)                             0.000000
# Youtube DL (Bytes)                           0.000000
# Youtube UL (Bytes)                           0.000000
# Netflix DL (Bytes)                           0.000000
# Netflix UL (Bytes)                           0.000000
# Gaming DL (Bytes)                            0.000000
# Gaming UL (Bytes)                            0.000000
# Other DL (Bytes)                             0.000000
# Other UL (Bytes)                             0.000000
# Total UL (Bytes)                             0.000667
# Total DL (Bytes)                             0.000667
# dtype: float64

# %%
#EDA Exploratory Data Analysis

# %%
#Statistics Summary for nummerical data type
dfa.describe().T
# Out:
#                                              count          mean  \
# Bearer Id                                 149010.0  1.013887e+19
# Start ms                                  150000.0  4.991882e+02
# End ms                                    150000.0  4.988009e+02
# Dur. (ms)                                 150000.0  1.046086e+05
# IMSI                                      149431.0  2.082016e+14
# MSISDN/Number                             148935.0  4.188282e+10
# IMEI                                      149429.0  4.847455e+13
# Avg RTT DL (ms)                           122172.0  1.097957e+02
# Avg RTT UL (ms)                           122189.0  1.766288e+01
# Avg Bearer TP DL (kbps)                   150000.0  1.330005e+04
# Avg Bearer TP UL (kbps)                   150000.0  1.770429e+03
# TCP DL Retrans. Vol (Bytes)                61855.0  2.080991e+07
# TCP UL Retrans. Vol (Bytes)                53352.0  7.596587e+05
# DL TP < 50 Kbps (%)                       149247.0  9.284475e+01
# 50 Kbps < DL TP < 250 Kbps (%)            149247.0  3.069355e+00
# 250 Kbps < DL TP < 1 Mbps (%)             149247.0  1.717341e+00
# DL TP > 1 Mbps (%)                        149247.0  1.609654e+00
# UL TP < 10 Kbps (%)                       149209.0  9.853014e+01
# 10 Kbps < UL TP < 50 Kbps (%)             149209.0  7.767494e-01
# 50 Kbps < UL TP < 300 Kbps (%)            149209.0  1.479871e-01
# UL TP > 300 Kbps (%)                      149209.0  7.892285e-02
# HTTP DL (Bytes)                            68527.0  1.144710e+08
# HTTP UL (Bytes)                            68191.0  3.242301e+06
# Activity Duration DL (ms)                 150000.0  1.829177e+06
# Activity Duration UL (ms)                 150000.0  1.408880e+06
# Dur. (ms).1                               150000.0  1.046091e+08
# Nb of sec with 125000B < Vol DL            52463.0  9.897000e+02
# Nb of sec with 1250B < Vol UL < 6250B      57107.0  3.404344e+02
# Nb of sec with 31250B < Vol DL < 125000B   56415.0  8.108374e+02
# Nb of sec with 37500B < Vol UL             19747.0  1.492571e+02
# Nb of sec with 6250B < Vol DL < 31250B     61684.0  9.654648e+02
# Nb of sec with 6250B < Vol UL < 37500B     38158.0  1.413048e+02
# Nb of sec with Vol DL < 6250B             149246.0  3.719788e+03
# Nb of sec with Vol UL < 1250B             149208.0  4.022083e+03
# Social Media DL (Bytes)                   150001.0  1.795322e+06
# Social Media UL (Bytes)                   150001.0  3.292843e+04
# Google DL (Bytes)                         150001.0  5.750753e+06
# Google UL (Bytes)                         150001.0  2.056542e+06
# Email DL (Bytes)                          150001.0  1.791729e+06
# Email UL (Bytes)                          150001.0  4.673734e+05
# Youtube DL (Bytes)                        150001.0  1.163407e+07
# Youtube UL (Bytes)                        150001.0  1.100941e+07
# Netflix DL (Bytes)                        150001.0  1.162685e+07
# Netflix UL (Bytes)                        150001.0  1.100175e+07
# Gaming DL (Bytes)                         150001.0  4.220447e+08
# Gaming UL (Bytes)                         150001.0  8.288398e+06
# Other DL (Bytes)                          150001.0  4.211005e+08
# Other UL (Bytes)                          150001.0  8.264799e+06
# Total UL (Bytes)                          150000.0  4.112121e+07
# Total DL (Bytes)                          150000.0  4.546434e+08
#
#                                                    std           min  \
# Bearer Id                                 2.893173e+18  6.917538e+18
# Start ms                                  2.886118e+02  0.000000e+00
# End ms                                    2.880977e+02  0.000000e+00
# Dur. (ms)                                 8.103762e+04  7.142000e+03
# IMSI                                      2.148809e+10  2.040471e+14
# MSISDN/Number                             2.447443e+12  3.360100e+10
# IMEI                                      2.241637e+13  4.400152e+11
# Avg RTT DL (ms)                           6.197827e+02  0.000000e+00
# Avg RTT UL (ms)                           8.479352e+01  0.000000e+00
# Avg Bearer TP DL (kbps)                   2.397188e+04  0.000000e+00
# Avg Bearer TP UL (kbps)                   4.625356e+03  0.000000e+00
# TCP DL Retrans. Vol (Bytes)               1.825665e+08  2.000000e+00
# TCP UL Retrans. Vol (Bytes)               2.645305e+07  1.000000e+00
# DL TP < 50 Kbps (%)                       1.303803e+01  0.000000e+00
# 50 Kbps < DL TP < 250 Kbps (%)            6.215233e+00  0.000000e+00
# 250 Kbps < DL TP < 1 Mbps (%)             4.159538e+00  0.000000e+00
# DL TP > 1 Mbps (%)                        4.828890e+00  0.000000e+00
# UL TP < 10 Kbps (%)                       4.634285e+00  0.000000e+00
# 10 Kbps < UL TP < 50 Kbps (%)             3.225176e+00  0.000000e+00
# 50 Kbps < UL TP < 300 Kbps (%)            1.624523e+00  0.000000e+00
# UL TP > 300 Kbps (%)                      1.295396e+00  0.000000e+00
# HTTP DL (Bytes)                           9.631946e+08  4.000000e+01
# HTTP UL (Bytes)                           1.957064e+07  4.000000e+01
# Activity Duration DL (ms)                 5.696395e+06  0.000000e+00
# Activity Duration UL (ms)                 4.643231e+06  0.000000e+00
# Dur. (ms).1                               8.103761e+07  7.142988e+06
# Nb of sec with 125000B < Vol DL           2.546524e+03  1.000000e+00
# Nb of sec with 1250B < Vol UL < 6250B     1.445365e+03  1.000000e+00
# Nb of sec with 31250B < Vol DL < 125000B  1.842162e+03  1.000000e+00
# Nb of sec with 37500B < Vol UL            1.219112e+03  1.000000e+00
# Nb of sec with 6250B < Vol DL < 31250B    1.946388e+03  1.000000e+00
# Nb of sec with 6250B < Vol UL < 37500B    9.933497e+02  1.000000e+00
# Nb of sec with Vol DL < 6250B             9.171609e+03  1.000000e+00
# Nb of sec with Vol UL < 1250B             1.016032e+04  1.000000e+00
# Social Media DL (Bytes)                   1.035482e+06  1.200000e+01
# Social Media UL (Bytes)                   1.900618e+04  0.000000e+00
# Google DL (Bytes)                         3.309097e+06  2.070000e+02
# Google UL (Bytes)                         1.189917e+06  3.000000e+00
# Email DL (Bytes)                          1.035840e+06  1.400000e+01
# Email UL (Bytes)                          2.699693e+05  2.000000e+00
# Youtube DL (Bytes)                        6.710569e+06  5.300000e+01
# Youtube UL (Bytes)                        6.345423e+06  1.050000e+02
# Netflix DL (Bytes)                        6.725218e+06  4.200000e+01
# Netflix UL (Bytes)                        6.359490e+06  3.500000e+01
# Gaming DL (Bytes)                         2.439675e+08  2.516000e+03
# Gaming UL (Bytes)                         4.782700e+06  5.900000e+01
# Other DL (Bytes)                          2.432050e+08  3.290000e+03
# Other UL (Bytes)                          4.769004e+06  1.480000e+02
# Total UL (Bytes)                          1.127639e+07  2.866892e+06
# Total DL (Bytes)                          2.441429e+08  7.114041e+06
#
#                                                    25%           50%  \
# Bearer Id                                 7.349883e+18  7.349883e+18
# Start ms                                  2.500000e+02  4.990000e+02
# End ms                                    2.510000e+02  5.000000e+02
# Dur. (ms)                                 5.744050e+04  8.639900e+04
# IMSI                                      2.082014e+14  2.082015e+14
# MSISDN/Number                             3.365130e+10  3.366371e+10
# IMEI                                      3.546071e+13  3.572201e+13
# Avg RTT DL (ms)                           3.200000e+01  4.500000e+01
# Avg RTT UL (ms)                           2.000000e+00  5.000000e+00
# Avg Bearer TP DL (kbps)                   4.300000e+01  6.300000e+01
# Avg Bearer TP UL (kbps)                   4.700000e+01  6.300000e+01
# TCP DL Retrans. Vol (Bytes)               3.565150e+04  5.687300e+05
# TCP UL Retrans. Vol (Bytes)               4.694750e+03  2.094950e+04
# DL TP < 50 Kbps (%)                       9.100000e+01  1.000000e+02
# 50 Kbps < DL TP < 250 Kbps (%)            0.000000e+00  0.000000e+00
# 250 Kbps < DL TP < 1 Mbps (%)             0.000000e+00  0.000000e+00
# DL TP > 1 Mbps (%)                        0.000000e+00  0.000000e+00
# UL TP < 10 Kbps (%)                       9.900000e+01  1.000000e+02
# 10 Kbps < UL TP < 50 Kbps (%)             0.000000e+00  0.000000e+00
# 50 Kbps < UL TP < 300 Kbps (%)            0.000000e+00  0.000000e+00
# UL TP > 300 Kbps (%)                      0.000000e+00  0.000000e+00
# HTTP DL (Bytes)                           1.124035e+05  1.941949e+06
# HTTP UL (Bytes)                           2.432200e+04  2.297330e+05
# Activity Duration DL (ms)                 1.487775e+04  3.930450e+04
# Activity Duration UL (ms)                 2.153975e+04  4.679350e+04
# Dur. (ms).1                               5.744079e+07  8.639998e+07
# Nb of sec with 125000B < Vol DL           2.000000e+01  1.280000e+02
# Nb of sec with 1250B < Vol UL < 6250B     1.000000e+01  5.200000e+01
# Nb of sec with 31250B < Vol DL < 125000B  2.600000e+01  1.640000e+02
# Nb of sec with 37500B < Vol UL            2.000000e+00  8.000000e+00
# Nb of sec with 6250B < Vol DL < 31250B    3.900000e+01  2.880000e+02
# Nb of sec with 6250B < Vol UL < 37500B    3.000000e+00  8.000000e+00
# Nb of sec with Vol DL < 6250B             8.700000e+01  2.030000e+02
# Nb of sec with Vol UL < 1250B             1.060000e+02  2.170000e+02
# Social Media DL (Bytes)                   8.991480e+05  1.794369e+06
# Social Media UL (Bytes)                   1.644800e+04  3.292000e+04
# Google DL (Bytes)                         2.882393e+06  5.765829e+06
# Google UL (Bytes)                         1.024279e+06  2.054573e+06
# Email DL (Bytes)                          8.927930e+05  1.793505e+06
# Email UL (Bytes)                          2.333830e+05  4.662500e+05
# Youtube DL (Bytes)                        5.833501e+06  1.161602e+07
# Youtube UL (Bytes)                        5.517965e+06  1.101345e+07
# Netflix DL (Bytes)                        5.777156e+06  1.164222e+07
# Netflix UL (Bytes)                        5.475981e+06  1.099638e+07
# Gaming DL (Bytes)                         2.104733e+08  4.234081e+08
# Gaming UL (Bytes)                         4.128476e+06  8.291208e+06
# Other DL (Bytes)                          2.101869e+08  4.218030e+08
# Other UL (Bytes)                          4.145943e+06  8.267071e+06
# Total UL (Bytes)                          3.322201e+07  4.114331e+07
# Total DL (Bytes)                          2.431068e+08  4.558411e+08
#
#                                                    75%           max
# Bearer Id                                 1.304243e+19  1.318654e+19
# Start ms                                  7.490000e+02  9.990000e+02
# End ms                                    7.500000e+02  9.990000e+02
# Dur. (ms)                                 1.324302e+05  1.859336e+06
# IMSI                                      2.082018e+14  2.140743e+14
# MSISDN/Number                             3.368349e+10  8.823971e+14
# IMEI                                      8.611970e+13  9.900120e+13
# Avg RTT DL (ms)                           7.000000e+01  9.692300e+04
# Avg RTT UL (ms)                           1.500000e+01  7.120000e+03
# Avg Bearer TP DL (kbps)                   1.971075e+04  3.781600e+05
# Avg Bearer TP UL (kbps)                   1.120000e+03  5.861300e+04
# TCP DL Retrans. Vol (Bytes)               3.768308e+06  4.294426e+09
# TCP UL Retrans. Vol (Bytes)               8.402025e+04  2.908226e+09
# DL TP < 50 Kbps (%)                       1.000000e+02  1.000000e+02
# 50 Kbps < DL TP < 250 Kbps (%)            4.000000e+00  9.300000e+01
# 250 Kbps < DL TP < 1 Mbps (%)             1.000000e+00  1.000000e+02
# DL TP > 1 Mbps (%)                        0.000000e+00  9.400000e+01
# UL TP < 10 Kbps (%)                       1.000000e+02  1.000000e+02
# 10 Kbps < UL TP < 50 Kbps (%)             0.000000e+00  9.800000e+01
# 50 Kbps < UL TP < 300 Kbps (%)            0.000000e+00  1.000000e+02
# UL TP > 300 Kbps (%)                      0.000000e+00  9.600000e+01
# HTTP DL (Bytes)                           2.504290e+07  7.253064e+10
# HTTP UL (Bytes)                           1.542827e+06  1.491890e+09
# Activity Duration DL (ms)                 6.796095e+05  1.365365e+08
# Activity Duration UL (ms)                 5.990952e+05  1.449113e+08
# Dur. (ms).1                               1.324308e+08  1.859336e+09
# Nb of sec with 125000B < Vol DL           6.935000e+02  8.147600e+04
# Nb of sec with 1250B < Vol UL < 6250B     2.030000e+02  8.541200e+04
# Nb of sec with 31250B < Vol DL < 125000B  7.570000e+02  5.852500e+04
# Nb of sec with 37500B < Vol UL            3.500000e+01  5.055300e+04
# Nb of sec with 6250B < Vol DL < 31250B    1.092000e+03  6.691300e+04
# Nb of sec with 6250B < Vol UL < 37500B    3.100000e+01  4.956500e+04
# Nb of sec with Vol DL < 6250B             2.650000e+03  6.040610e+05
# Nb of sec with Vol UL < 1250B             2.451000e+03  6.041220e+05
# Social Media DL (Bytes)                   2.694938e+06  3.586064e+06
# Social Media UL (Bytes)                   4.933400e+04  6.587000e+04
# Google DL (Bytes)                         8.623552e+06  1.146283e+07
# Google UL (Bytes)                         3.088454e+06  4.121357e+06
# Email DL (Bytes)                          2.689327e+06  3.586146e+06
# Email UL (Bytes)                          7.004400e+05  9.364180e+05
# Youtube DL (Bytes)                        1.744852e+07  2.325910e+07
# Youtube UL (Bytes)                        1.651556e+07  2.201196e+07
# Netflix DL (Bytes)                        1.747048e+07  2.325919e+07
# Netflix UL (Bytes)                        1.650727e+07  2.201196e+07
# Gaming DL (Bytes)                         6.331742e+08  8.434419e+08
# Gaming UL (Bytes)                         1.243162e+07  1.655879e+07
# Other DL (Bytes)                          6.316918e+08  8.434425e+08
# Other UL (Bytes)                          1.238415e+07  1.655882e+07
# Total UL (Bytes)                          4.903424e+07  7.833131e+07
# Total DL (Bytes)                          6.657055e+08  9.029696e+08

# %%
#for specific variable
dfa['Total UL (Bytes)'].describe().T
# Out:
# count    1.500000e+05
# mean     4.112121e+07
# std      1.127639e+07
# min      2.866892e+06
# 25%      3.322201e+07
# 50%      4.114331e+07
# 75%      4.903424e+07
# max      7.833131e+07
# Name: Total UL (Bytes), dtype: float64

# %%
#Statistics Summary for all(including object and category)
dfa.describe(include='all').T
# Out:
#                                              count unique               top  \
# Bearer Id                                 149010.0    NaN               NaN
# Start                                       150000   9997    4/26/2019 7:25
# Start ms                                  150000.0    NaN               NaN
# End                                         150000   6403    4/25/2019 0:01
# End ms                                    150000.0    NaN               NaN
# Dur. (ms)                                 150000.0    NaN               NaN
# IMSI                                      149431.0    NaN               NaN
# MSISDN/Number                             148935.0    NaN               NaN
# IMEI                                      149429.0    NaN               NaN
# Last Location Name                          148848  45547           D41377B
# Avg RTT DL (ms)                           122172.0    NaN               NaN
# Avg RTT UL (ms)                           122189.0    NaN               NaN
# Avg Bearer TP DL (kbps)                   150000.0    NaN               NaN
# Avg Bearer TP UL (kbps)                   150000.0    NaN               NaN
# TCP DL Retrans. Vol (Bytes)                61855.0    NaN               NaN
# TCP UL Retrans. Vol (Bytes)                53352.0    NaN               NaN
# DL TP < 50 Kbps (%)                       149247.0    NaN               NaN
# 50 Kbps < DL TP < 250 Kbps (%)            149247.0    NaN               NaN
# 250 Kbps < DL TP < 1 Mbps (%)             149247.0    NaN               NaN
# DL TP > 1 Mbps (%)                        149247.0    NaN               NaN
# UL TP < 10 Kbps (%)                       149209.0    NaN               NaN
# 10 Kbps < UL TP < 50 Kbps (%)             149209.0    NaN               NaN
# 50 Kbps < UL TP < 300 Kbps (%)            149209.0    NaN               NaN
# UL TP > 300 Kbps (%)                      149209.0    NaN               NaN
# HTTP DL (Bytes)                            68527.0    NaN               NaN
# HTTP UL (Bytes)                            68191.0    NaN               NaN
# Activity Duration DL (ms)                 150000.0    NaN               NaN
# Activity Duration UL (ms)                 150000.0    NaN               NaN
# Dur. (ms).1                               150000.0    NaN               NaN
# Handset Manufacturer                        149429    170             Apple
# Handset Type                                149429   1396  Huawei B528S-23A
# Nb of sec with 125000B < Vol DL            52463.0    NaN               NaN
# Nb of sec with 1250B < Vol UL < 6250B      57107.0    NaN               NaN
# Nb of sec with 31250B < Vol DL < 125000B   56415.0    NaN               NaN
# Nb of sec with 37500B < Vol UL             19747.0    NaN               NaN
# Nb of sec with 6250B < Vol DL < 31250B     61684.0    NaN               NaN
# Nb of sec with 6250B < Vol UL < 37500B     38158.0    NaN               NaN
# Nb of sec with Vol DL < 6250B             149246.0    NaN               NaN
# Nb of sec with Vol UL < 1250B             149208.0    NaN               NaN
# Social Media DL (Bytes)                   150001.0    NaN               NaN
# Social Media UL (Bytes)                   150001.0    NaN               NaN
# Google DL (Bytes)                         150001.0    NaN               NaN
# Google UL (Bytes)                         150001.0    NaN               NaN
# Email DL (Bytes)                          150001.0    NaN               NaN
# Email UL (Bytes)                          150001.0    NaN               NaN
# Youtube DL (Bytes)                        150001.0    NaN               NaN
# Youtube UL (Bytes)                        150001.0    NaN               NaN
# Netflix DL (Bytes)                        150001.0    NaN               NaN
# Netflix UL (Bytes)                        150001.0    NaN               NaN
# Gaming DL (Bytes)                         150001.0    NaN               NaN
# Gaming UL (Bytes)                         150001.0    NaN               NaN
# Other DL (Bytes)                          150001.0    NaN               NaN
# Other UL (Bytes)                          150001.0    NaN               NaN
# Total UL (Bytes)                          150000.0    NaN               NaN
# Total DL (Bytes)                          150000.0    NaN               NaN
#
#                                            freq                    mean  \
# Bearer Id                                   NaN  10138874654256340992.0
# Start                                       203                     NaN
# Start ms                                    NaN                499.1882
# End                                        1150                     NaN
# End ms                                      NaN               498.80088
# Dur. (ms)                                   NaN           104608.560347
# IMSI                                        NaN   208201639651669.03125
# MSISDN/Number                               NaN      41882819545.027359
# IMEI                                        NaN    48474547977654.53125
# Last Location Name                           80                     NaN
# Avg RTT DL (ms)                             NaN              109.795706
# Avg RTT UL (ms)                             NaN               17.662883
# Avg Bearer TP DL (kbps)                     NaN            13300.045927
# Avg Bearer TP UL (kbps)                     NaN             1770.428647
# TCP DL Retrans. Vol (Bytes)                 NaN         20809914.270342
# TCP UL Retrans. Vol (Bytes)                 NaN           759658.664811
# DL TP < 50 Kbps (%)                         NaN               92.844754
# 50 Kbps < DL TP < 250 Kbps (%)              NaN                3.069355
# 250 Kbps < DL TP < 1 Mbps (%)               NaN                1.717341
# DL TP > 1 Mbps (%)                          NaN                1.609654
# UL TP < 10 Kbps (%)                         NaN               98.530142
# 10 Kbps < UL TP < 50 Kbps (%)               NaN                0.776749
# 50 Kbps < UL TP < 300 Kbps (%)              NaN                0.147987
# UL TP > 300 Kbps (%)                        NaN                0.078923
# HTTP DL (Bytes)                             NaN        114471023.701884
# HTTP UL (Bytes)                             NaN          3242301.384875
# Activity Duration DL (ms)                   NaN          1829176.871833
# Activity Duration UL (ms)                   NaN           1408879.96752
# Dur. (ms).1                                 NaN        104609105.546013
# Handset Manufacturer                      59565                     NaN
# Handset Type                              19752                     NaN
# Nb of sec with 125000B < Vol DL             NaN              989.699998
# Nb of sec with 1250B < Vol UL < 6250B       NaN              340.434395
# Nb of sec with 31250B < Vol DL < 125000B    NaN              810.837401
# Nb of sec with 37500B < Vol UL              NaN              149.257052
# Nb of sec with 6250B < Vol DL < 31250B      NaN              965.464756
# Nb of sec with 6250B < Vol UL < 37500B      NaN              141.304812
# Nb of sec with Vol DL < 6250B               NaN             3719.787552
# Nb of sec with Vol UL < 1250B               NaN             4022.083454
# Social Media DL (Bytes)                     NaN          1795321.773647
# Social Media UL (Bytes)                     NaN             32928.43438
# Google DL (Bytes)                           NaN          5750752.619287
# Google UL (Bytes)                           NaN          2056541.926287
# Email DL (Bytes)                            NaN           1791728.86802
# Email UL (Bytes)                            NaN            467373.44194
# Youtube DL (Bytes)                          NaN           11634072.5039
# Youtube UL (Bytes)                          NaN           11009410.1347
# Netflix DL (Bytes)                          NaN          11626851.71874
# Netflix UL (Bytes)                          NaN          11001754.81964
# Gaming DL (Bytes)                           NaN        422044702.595373
# Gaming UL (Bytes)                           NaN          8288398.110733
# Other DL (Bytes)                            NaN        421100544.194493
# Other UL (Bytes)                            NaN          8264799.424427
# Total UL (Bytes)                            NaN         41121206.292107
# Total DL (Bytes)                            NaN        454643430.078967
#
#                                                             std  \
# Bearer Id                                 2893172512268410880.0
# Start                                                       NaN
# Start ms                                             288.611834
# End                                                         NaN
# End ms                                               288.097653
# Dur. (ms)                                          81037.621479
# IMSI                                         21488090841.366325
# MSISDN/Number                              2447443358621.665039
# IMEI                                      22416372027957.558594
# Last Location Name                                          NaN
# Avg RTT DL (ms)                                      619.782739
# Avg RTT UL (ms)                                       84.793524
# Avg Bearer TP DL (kbps)                            23971.878541
# Avg Bearer TP UL (kbps)                               4625.3555
# TCP DL Retrans. Vol (Bytes)                    182566527.914748
# TCP UL Retrans. Vol (Bytes)                     26453047.172167
# DL TP < 50 Kbps (%)                                   13.038031
# 50 Kbps < DL TP < 250 Kbps (%)                         6.215233
# 250 Kbps < DL TP < 1 Mbps (%)                          4.159538
# DL TP > 1 Mbps (%)                                      4.82889
# UL TP < 10 Kbps (%)                                    4.634285
# 10 Kbps < UL TP < 50 Kbps (%)                          3.225176
# 50 Kbps < UL TP < 300 Kbps (%)                         1.624523
# UL TP > 300 Kbps (%)                                   1.295396
# HTTP DL (Bytes)                                963194563.977449
# HTTP UL (Bytes)                                 19570643.166646
# Activity Duration DL (ms)                         5696395.46552
# Activity Duration UL (ms)                        4643230.599005
# Dur. (ms).1                                      81037611.57679
# Handset Manufacturer                                        NaN
# Handset Type                                                NaN
# Nb of sec with 125000B < Vol DL                      2546.52444
# Nb of sec with 1250B < Vol UL < 6250B               1445.365032
# Nb of sec with 31250B < Vol DL < 125000B            1842.162008
# Nb of sec with 37500B < Vol UL                      1219.112287
# Nb of sec with 6250B < Vol DL < 31250B              1946.387608
# Nb of sec with 6250B < Vol UL < 37500B               993.349688
# Nb of sec with Vol DL < 6250B                        9171.60901
# Nb of sec with Vol UL < 1250B                      10160.324314
# Social Media DL (Bytes)                          1035482.275953
# Social Media UL (Bytes)                            19006.178256
# Google DL (Bytes)                                3309097.017369
# Google UL (Bytes)                                1189916.926004
# Email DL (Bytes)                                 1035839.510337
# Email UL (Bytes)                                  269969.307031
# Youtube DL (Bytes)                                6710568.85019
# Youtube UL (Bytes)                               6345423.354476
# Netflix DL (Bytes)                               6725218.026494
# Netflix UL (Bytes)                               6359489.759475
# Gaming DL (Bytes)                              243967494.346378
# Gaming UL (Bytes)                                4782699.656232
# Other DL (Bytes)                               243205009.808155
# Other UL (Bytes)                                 4769003.686403
# Total UL (Bytes)                                11276386.514689
# Total DL (Bytes)                               244142874.376284
#
#                                                             min  \
# Bearer Id                                 6917537518543529984.0
# Start                                                       NaN
# Start ms                                                    0.0
# End                                                         NaN
# End ms                                                      0.0
# Dur. (ms)                                                7142.0
# IMSI                                          204047108489451.0
# MSISDN/Number                                     33601001722.0
# IMEI                                             440015202000.0
# Last Location Name                                          NaN
# Avg RTT DL (ms)                                             0.0
# Avg RTT UL (ms)                                             0.0
# Avg Bearer TP DL (kbps)                                     0.0
# Avg Bearer TP UL (kbps)                                     0.0
# TCP DL Retrans. Vol (Bytes)                                 2.0
# TCP UL Retrans. Vol (Bytes)                                 1.0
# DL TP < 50 Kbps (%)                                         0.0
# 50 Kbps < DL TP < 250 Kbps (%)                              0.0
# 250 Kbps < DL TP < 1 Mbps (%)                               0.0
# DL TP > 1 Mbps (%)                                          0.0
# UL TP < 10 Kbps (%)                                         0.0
# 10 Kbps < UL TP < 50 Kbps (%)                               0.0
# 50 Kbps < UL TP < 300 Kbps (%)                              0.0
# UL TP > 300 Kbps (%)                                        0.0
# HTTP DL (Bytes)                                            40.0
# HTTP UL (Bytes)                                            40.0
# Activity Duration DL (ms)                                   0.0
# Activity Duration UL (ms)                                   0.0
# Dur. (ms).1                                           7142988.0
# Handset Manufacturer                                        NaN
# Handset Type                                                NaN
# Nb of sec with 125000B < Vol DL                             1.0
# Nb of sec with 1250B < Vol UL < 6250B                       1.0
# Nb of sec with 31250B < Vol DL < 125000B                    1.0
# Nb of sec with 37500B < Vol UL                              1.0
# Nb of sec with 6250B < Vol DL < 31250B                      1.0
# Nb of sec with 6250B < Vol UL < 37500B                      1.0
# Nb of sec with Vol DL < 6250B                               1.0
# Nb of sec with Vol UL < 1250B                               1.0
# Social Media DL (Bytes)                                    12.0
# Social Media UL (Bytes)                                     0.0
# Google DL (Bytes)                                         207.0
# Google UL (Bytes)                                           3.0
# Email DL (Bytes)                                           14.0
# Email UL (Bytes)                                            2.0
# Youtube DL (Bytes)                                         53.0
# Youtube UL (Bytes)                                        105.0
# Netflix DL (Bytes)                                         42.0
# Netflix UL (Bytes)                                         35.0
# Gaming DL (Bytes)                                        2516.0
# Gaming UL (Bytes)                                          59.0
# Other DL (Bytes)                                         3290.0
# Other UL (Bytes)                                          148.0
# Total UL (Bytes)                                      2866892.0
# Total DL (Bytes)                                      7114041.0
#
#                                                             25%  \
# Bearer Id                                 7349883246953990144.0
# Start                                                       NaN
# Start ms                                                  250.0
# End                                                         NaN
# End ms                                                    251.0
# Dur. (ms)                                               57440.5
# IMSI                                          208201401263249.0
# MSISDN/Number                                     33651295581.5
# IMEI                                           35460708865439.0
# Last Location Name                                          NaN
# Avg RTT DL (ms)                                            32.0
# Avg RTT UL (ms)                                             2.0
# Avg Bearer TP DL (kbps)                                    43.0
# Avg Bearer TP UL (kbps)                                    47.0
# TCP DL Retrans. Vol (Bytes)                             35651.5
# TCP UL Retrans. Vol (Bytes)                             4694.75
# DL TP < 50 Kbps (%)                                        91.0
# 50 Kbps < DL TP < 250 Kbps (%)                              0.0
# 250 Kbps < DL TP < 1 Mbps (%)                               0.0
# DL TP > 1 Mbps (%)                                          0.0
# UL TP < 10 Kbps (%)                                        99.0
# 10 Kbps < UL TP < 50 Kbps (%)                               0.0
# 50 Kbps < UL TP < 300 Kbps (%)                              0.0
# UL TP > 300 Kbps (%)                                        0.0
# HTTP DL (Bytes)                                        112403.5
# HTTP UL (Bytes)                                         24322.0
# Activity Duration DL (ms)                              14877.75
# Activity Duration UL (ms)                              21539.75
# Dur. (ms).1                                         57440785.25
# Handset Manufacturer                                        NaN
# Handset Type                                                NaN
# Nb of sec with 125000B < Vol DL                            20.0
# Nb of sec with 1250B < Vol UL < 6250B                      10.0
# Nb of sec with 31250B < Vol DL < 125000B                   26.0
# Nb of sec with 37500B < Vol UL                              2.0
# Nb of sec with 6250B < Vol DL < 31250B                     39.0
# Nb of sec with 6250B < Vol UL < 37500B                      3.0
# Nb of sec with Vol DL < 6250B                              87.0
# Nb of sec with Vol UL < 1250B                             106.0
# Social Media DL (Bytes)                                899148.0
# Social Media UL (Bytes)                                 16448.0
# Google DL (Bytes)                                     2882393.0
# Google UL (Bytes)                                     1024279.0
# Email DL (Bytes)                                       892793.0
# Email UL (Bytes)                                       233383.0
# Youtube DL (Bytes)                                    5833501.0
# Youtube UL (Bytes)                                    5517965.0
# Netflix DL (Bytes)                                    5777156.0
# Netflix UL (Bytes)                                    5475981.0
# Gaming DL (Bytes)                                   210473253.0
# Gaming UL (Bytes)                                     4128476.0
# Other DL (Bytes)                                    210186872.0
# Other UL (Bytes)                                      4145943.0
# Total UL (Bytes)                                     33222010.5
# Total DL (Bytes)                                    243106803.0
#
#                                                             50%  \
# Bearer Id                                 7349883264156584960.0
# Start                                                       NaN
# Start ms                                                  499.0
# End                                                         NaN
# End ms                                                    500.0
# Dur. (ms)                                               86399.0
# IMSI                                          208201546329113.0
# MSISDN/Number                                     33663706799.0
# IMEI                                           35722009426311.0
# Last Location Name                                          NaN
# Avg RTT DL (ms)                                            45.0
# Avg RTT UL (ms)                                             5.0
# Avg Bearer TP DL (kbps)                                    63.0
# Avg Bearer TP UL (kbps)                                    63.0
# TCP DL Retrans. Vol (Bytes)                            568730.0
# TCP UL Retrans. Vol (Bytes)                             20949.5
# DL TP < 50 Kbps (%)                                       100.0
# 50 Kbps < DL TP < 250 Kbps (%)                              0.0
# 250 Kbps < DL TP < 1 Mbps (%)                               0.0
# DL TP > 1 Mbps (%)                                          0.0
# UL TP < 10 Kbps (%)                                       100.0
# 10 Kbps < UL TP < 50 Kbps (%)                               0.0
# 50 Kbps < UL TP < 300 Kbps (%)                              0.0
# UL TP > 300 Kbps (%)                                        0.0
# HTTP DL (Bytes)                                       1941949.0
# HTTP UL (Bytes)                                        229733.0
# Activity Duration DL (ms)                               39304.5
# Activity Duration UL (ms)                               46793.5
# Dur. (ms).1                                          86399983.0
# Handset Manufacturer                                        NaN
# Handset Type                                                NaN
# Nb of sec with 125000B < Vol DL                           128.0
# Nb of sec with 1250B < Vol UL < 6250B                      52.0
# Nb of sec with 31250B < Vol DL < 125000B                  164.0
# Nb of sec with 37500B < Vol UL                              8.0
# Nb of sec with 6250B < Vol DL < 31250B                    288.0
# Nb of sec with 6250B < Vol UL < 37500B                      8.0
# Nb of sec with Vol DL < 6250B                             203.0
# Nb of sec with Vol UL < 1250B                             217.0
# Social Media DL (Bytes)                               1794369.0
# Social Media UL (Bytes)                                 32920.0
# Google DL (Bytes)                                     5765829.0
# Google UL (Bytes)                                     2054573.0
# Email DL (Bytes)                                      1793505.0
# Email UL (Bytes)                                       466250.0
# Youtube DL (Bytes)                                   11616019.0
# Youtube UL (Bytes)                                   11013447.0
# Netflix DL (Bytes)                                   11642217.0
# Netflix UL (Bytes)                                   10996384.0
# Gaming DL (Bytes)                                   423408104.0
# Gaming UL (Bytes)                                     8291208.0
# Other DL (Bytes)                                    421803006.0
# Other UL (Bytes)                                      8267071.0
# Total UL (Bytes)                                     41143312.0
# Total DL (Bytes)                                    455841077.5
#
#                                                              75%  \
# Bearer Id                                 13042425978957576192.0
# Start                                                        NaN
# Start ms                                                   749.0
# End                                                          NaN
# End ms                                                     750.0
# Dur. (ms)                                              132430.25
# IMSI                                           208201771619103.0
# MSISDN/Number                                      33683490769.0
# IMEI                                            86119704674953.0
# Last Location Name                                           NaN
# Avg RTT DL (ms)                                             70.0
# Avg RTT UL (ms)                                             15.0
# Avg Bearer TP DL (kbps)                                 19710.75
# Avg Bearer TP UL (kbps)                                   1120.0
# TCP DL Retrans. Vol (Bytes)                            3768308.5
# TCP UL Retrans. Vol (Bytes)                             84020.25
# DL TP < 50 Kbps (%)                                        100.0
# 50 Kbps < DL TP < 250 Kbps (%)                               4.0
# 250 Kbps < DL TP < 1 Mbps (%)                                1.0
# DL TP > 1 Mbps (%)                                           0.0
# UL TP < 10 Kbps (%)                                        100.0
# 10 Kbps < UL TP < 50 Kbps (%)                                0.0
# 50 Kbps < UL TP < 300 Kbps (%)                               0.0
# UL TP > 300 Kbps (%)                                         0.0
# HTTP DL (Bytes)                                       25042903.5
# HTTP UL (Bytes)                                        1542827.0
# Activity Duration DL (ms)                               679609.5
# Activity Duration UL (ms)                              599095.25
# Dur. (ms).1                                          132430782.0
# Handset Manufacturer                                         NaN
# Handset Type                                                 NaN
# Nb of sec with 125000B < Vol DL                            693.5
# Nb of sec with 1250B < Vol UL < 6250B                      203.0
# Nb of sec with 31250B < Vol DL < 125000B                   757.0
# Nb of sec with 37500B < Vol UL                              35.0
# Nb of sec with 6250B < Vol DL < 31250B                    1092.0
# Nb of sec with 6250B < Vol UL < 37500B                      31.0
# Nb of sec with Vol DL < 6250B                             2650.0
# Nb of sec with Vol UL < 1250B                             2451.0
# Social Media DL (Bytes)                                2694938.0
# Social Media UL (Bytes)                                  49334.0
# Google DL (Bytes)                                      8623552.0
# Google UL (Bytes)                                      3088454.0
# Email DL (Bytes)                                       2689327.0
# Email UL (Bytes)                                        700440.0
# Youtube DL (Bytes)                                    17448518.0
# Youtube UL (Bytes)                                    16515562.0
# Netflix DL (Bytes)                                    17470478.0
# Netflix UL (Bytes)                                    16507268.0
# Gaming DL (Bytes)                                    633174167.0
# Gaming UL (Bytes)                                     12431624.0
# Other DL (Bytes)                                     631691786.0
# Other UL (Bytes)                                      12384148.0
# Total UL (Bytes)                                      49034238.5
# Total DL (Bytes)                                     665705544.0
#
#                                                              max
# Bearer Id                                 13186541167134199808.0
# Start                                                        NaN
# Start ms                                                   999.0
# End                                                          NaN
# End ms                                                     999.0
# Dur. (ms)                                              1859336.0
# IMSI                                           214074303349628.0
# MSISDN/Number                                  882397108489451.0
# IMEI                                            99001201327774.0
# Last Location Name                                           NaN
# Avg RTT DL (ms)                                          96923.0
# Avg RTT UL (ms)                                           7120.0
# Avg Bearer TP DL (kbps)                                 378160.0
# Avg Bearer TP UL (kbps)                                  58613.0
# TCP DL Retrans. Vol (Bytes)                         4294425570.0
# TCP UL Retrans. Vol (Bytes)                         2908226006.0
# DL TP < 50 Kbps (%)                                        100.0
# 50 Kbps < DL TP < 250 Kbps (%)                              93.0
# 250 Kbps < DL TP < 1 Mbps (%)                              100.0
# DL TP > 1 Mbps (%)                                          94.0
# UL TP < 10 Kbps (%)                                        100.0
# 10 Kbps < UL TP < 50 Kbps (%)                               98.0
# 50 Kbps < UL TP < 300 Kbps (%)                             100.0
# UL TP > 300 Kbps (%)                                        96.0
# HTTP DL (Bytes)                                    72530636168.0
# HTTP UL (Bytes)                                     1491889672.0
# Activity Duration DL (ms)                            136536461.0
# Activity Duration UL (ms)                            144911293.0
# Dur. (ms).1                                         1859336442.0
# Handset Manufacturer                                         NaN
# Handset Type                                                 NaN
# Nb of sec with 125000B < Vol DL                          81476.0
# Nb of sec with 1250B < Vol UL < 6250B                    85412.0
# Nb of sec with 31250B < Vol DL < 125000B                 58525.0
# Nb of sec with 37500B < Vol UL                           50553.0
# Nb of sec with 6250B < Vol DL < 31250B                   66913.0
# Nb of sec with 6250B < Vol UL < 37500B                   49565.0
# Nb of sec with Vol DL < 6250B                           604061.0
# Nb of sec with Vol UL < 1250B                           604122.0
# Social Media DL (Bytes)                                3586064.0
# Social Media UL (Bytes)                                  65870.0
# Google DL (Bytes)                                     11462832.0
# Google UL (Bytes)                                      4121357.0
# Email DL (Bytes)                                       3586146.0
# Email UL (Bytes)                                        936418.0
# Youtube DL (Bytes)                                    23259098.0
# Youtube UL (Bytes)                                    22011962.0
# Netflix DL (Bytes)                                    23259189.0
# Netflix UL (Bytes)                                    22011955.0
# Gaming DL (Bytes)                                    843441889.0
# Gaming UL (Bytes)                                     16558794.0
# Other DL (Bytes)                                     843442489.0
# Other UL (Bytes)                                      16558816.0
# Total UL (Bytes)                                      78331311.0
# Total DL (Bytes)                                     902969616.0

# %%
#Handling missing data

# how many missing values exist or better still what is the % of missing values in the dataset?
def percent_missing(dfa):
    # Calculate total number of cells in dataframe
    totalCells = np.product(dfa.shape)

    # Count number of missing values per column
    missingCount = dfa.isnull().sum()

    # Calculate total number of missing values
    totalMissing = missingCount.sum()

    # Calculate percentage of missing values
    print("The telecom dataset contains", round(((totalMissing/totalCells) * 100), 2), "%", "missing values.")

percent_missing(dfa)
# Out:
# The telecom dataset contains 12.5 % missing values.

# %%
#Aggregate per user 
#number of xDR sessions
sessions = dfa.count()

print("Number of xDR sessions:", sessions)
# Out:
# Number of xDR sessions: Bearer Id                                   149010
# Start                                       150000
# Start ms                                    150000
# End                                         150000
# End ms                                      150000
# Dur. (ms)                                   150000
# IMSI                                        149431
# MSISDN/Number                               148935
# IMEI                                        149429
# Last Location Name                          148848
# Avg RTT DL (ms)                             122172
# Avg RTT UL (ms)                             122189
# Avg Bearer TP DL (kbps)                     150000
# Avg Bearer TP UL (kbps)                     150000
# TCP DL Retrans. Vol (Bytes)                  61855
# TCP UL Retrans. Vol (Bytes)                  53352
# DL TP < 50 Kbps (%)                         149247
# 50 Kbps < DL TP < 250 Kbps (%)              149247
# 250 Kbps < DL TP < 1 Mbps (%)               149247
# DL TP > 1 Mbps (%)                          149247
# UL TP < 10 Kbps (%)                         149209
# 10 Kbps < UL TP < 50 Kbps (%)               149209
# 50 Kbps < UL TP < 300 Kbps (%)              149209
# UL TP > 300 Kbps (%)                        149209
# HTTP DL (Bytes)                              68527
# HTTP UL (Bytes)                              68191
# Activity Duration DL (ms)                   150000
# Activity Duration UL (ms)                   150000
# Dur. (ms).1                                 150000
# Handset Manufacturer                        149429
# Handset Type                                149429
# Nb of sec with 125000B < Vol DL              52463
# Nb of sec with 1250B < Vol UL < 6250B        57107
# Nb of sec with 31250B < Vol DL < 125000B     56415
# Nb of sec with 37500B < Vol UL               19747
# Nb of sec with 6250B < Vol DL < 31250B       61684
# Nb of sec with 6250B < Vol UL < 37500B       38158
# Nb of sec with Vol DL < 6250B               149246
# Nb of sec with Vol UL < 1250B               149208
# Social Media DL (Bytes)                     150001
# Social Media UL (Bytes)                     150001
# Google DL (Bytes)                           150001
# Google UL (Bytes)                           150001
# Email DL (Bytes)                            150001
# Email UL (Bytes)                            150001
# Youtube DL (Bytes)                          150001
# Youtube UL (Bytes)                          150001
# Netflix DL (Bytes)                          150001
# Netflix UL (Bytes)                          150001
# Gaming DL (Bytes)                           150001
# Gaming UL (Bytes)                           150001
# Other DL (Bytes)                            150001
# Other UL (Bytes)                            150001
# Total UL (Bytes)                            150000
# Total DL (Bytes)                            150000
# dtype: int64

# %%
#Number of session durations
session_durations = dfa['Dur. (ms)'].count()

print("Number of session durations:", session_durations)
# Out:
# Number of session durations: 150000

# %%
#the total download (DL) and upload (UL) data
total_dl_data = dfa['Total DL (Bytes)'].sum()
total_ul_data = dfa['Total UL (Bytes)'].sum()

print("Total Download Data:", total_dl_data, "bytes")
print("Total Upload Data:", total_ul_data, "bytes")
# Out:
# Total Download Data: 68196514511845.0 bytes
# Total Upload Data: 6168180943816.0 bytes

# %%
#the total data volume (in Bytes) during this session for each application
total_social_media_dl = dfa['Social Media DL (Bytes)'].sum()
total_social_media_ul = dfa['Social Media UL (Bytes)'].sum()
total_google_dl = dfa['Google DL (Bytes)'].sum()
total_google_ul = dfa['Google UL (Bytes)'].sum()
total_email_dl = dfa['Email DL (Bytes)'].sum()
total_email_ul = dfa['Email UL (Bytes)'].sum()
total_youtube_dl = dfa['Youtube DL (Bytes)'].sum()
total_youtube_ul = dfa['Youtube UL (Bytes)'].sum()
total_netflix_dl = dfa['Netflix DL (Bytes)'].sum()
total_netflix_ul = dfa['Netflix UL (Bytes)'].sum()
total_gaming_dl = dfa['Gaming DL (Bytes)'].sum()
total_gaming_ul = dfa['Gaming UL (Bytes)'].sum()
total_other_dl = dfa['Other DL (Bytes)'].sum()
total_other_ul = dfa['Other UL (Bytes)'].sum()

print("Total Social Media Data (DL):", total_social_media_dl, "bytes")
print("Total Social Media Data (UL):", total_social_media_ul, "bytes")
print("Total Google Data (DL):", total_google_dl, "bytes")
print("Total Google Data (UL):", total_google_ul, "bytes")
print("Total Email Data (DL):", total_email_dl, "bytes")
print("Total Email Data (UL):", total_email_ul, "bytes")
print("Total YouTube Data (DL):", total_youtube_dl, "bytes")
print("Total YouTube Data (UL):", total_youtube_ul, "bytes")
print("Total Netflix Data (DL):", total_netflix_dl, "bytes")
print("Total Netflix Data (UL):", total_netflix_ul, "bytes")
print("Total Gaming Data (DL):", total_gaming_dl, "bytes")
print("Total Gaming Data (UL):", total_gaming_ul, "bytes")
print("Total Other Data (DL):", total_other_dl, "bytes")
print("Total Other Data (UL):", total_other_ul, "bytes")
# Out:
# Total Social Media Data (DL): 269300061368.77365 bytes
# Total Social Media Data (UL): 4939298085.43438 bytes
# Total Google Data (DL): 862618643645.6193 bytes
# Total Google Data (UL): 308483345484.9263 bytes
# Total Email Data (DL): 268761121931.868 bytes
# Total Email Data (UL): 70106483664.44194 bytes
# Total YouTube Data (DL): 1745122509657.504 bytes
# Total YouTube Data (UL): 1651422529615.1348 bytes
# Total Netflix Data (DL): 1744039384662.7188 bytes
# Total Netflix Data (UL): 1650274224700.8196 bytes
# Total Gaming Data (DL): 63307127434008.59 bytes
# Total Gaming Data (UL): 1243268005008.1108 bytes
# Total Other Data (DL): 63165502729718.195 bytes
# Total Other Data (UL): 1239728178463.4243 bytes

# %%
#EDA Univariate Analysis(exploring individual variables)
#Let's separate Numerical and categorical variables for analysis
num_cols = dfa.select_dtypes(include=np.number).columns.tolist()
cat_cols=dfa.select_dtypes(include=['object']).columns

# %%
#Univariate analysis using Histogram and Box Plot
for col in num_cols:
    print(col)
    print('Skew :', round(dfa[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    dfa[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=dfa[col])
    plt.show()
# Out:
# Bearer Id
# Skew : 0.03
# Start ms
# Skew : 0.0
# End ms
# Skew : -0.0
# Dur. (ms)
# Skew : 3.95
# IMSI
# Skew : 41.05
# MSISDN/Number
# Skew : 332.16
# IMEI
# Skew : 1.07
# Avg RTT DL (ms)
# Skew : 62.91
# Avg RTT UL (ms)
# Skew : 28.46
# Avg Bearer TP DL (kbps)
# Skew : 2.59
# Avg Bearer TP UL (kbps)
# Skew : 4.5
# TCP DL Retrans. Vol (Bytes)
# Skew : 15.95
# TCP UL Retrans. Vol (Bytes)
# Skew : 84.11
# DL TP < 50 Kbps (%)
# Skew : -2.3
# 50 Kbps < DL TP < 250 Kbps (%)
# Skew : 3.27
# 250 Kbps < DL TP < 1 Mbps (%)
# Skew : 4.57
# DL TP > 1 Mbps (%)
# Skew : 5.37
# UL TP < 10 Kbps (%)
# Skew : -8.99
# 10 Kbps < UL TP < 50 Kbps (%)
# Skew : 10.94
# 50 Kbps < UL TP < 300 Kbps (%)
# Skew : 21.88
# UL TP > 300 Kbps (%)
# Skew : 36.17
# HTTP DL (Bytes)
# Skew : 38.94
# HTTP UL (Bytes)
# Skew : 32.47
# Activity Duration DL (ms)
# Skew : 5.87
# Activity Duration UL (ms)
# Skew : 7.38
# Dur. (ms).1
# Skew : 3.95
# Nb of sec with 125000B < Vol DL
# Skew : 6.59
# Nb of sec with 1250B < Vol UL < 6250B
# Skew : 22.04
# Nb of sec with 31250B < Vol DL < 125000B
# Skew : 6.61
# Nb of sec with 37500B < Vol UL
# Skew : 21.56
# Nb of sec with 6250B < Vol DL < 31250B
# Skew : 6.9
# Nb of sec with 6250B < Vol UL < 37500B
# Skew : 19.64
# Nb of sec with Vol DL < 6250B
# Skew : 9.04
# Nb of sec with Vol UL < 1250B
# Skew : 7.5
# Social Media DL (Bytes)
# Skew : -0.0
# Social Media UL (Bytes)
# Skew : -0.0
# Google DL (Bytes)
# Skew : -0.01
# Google UL (Bytes)
# Skew : 0.0
# Email DL (Bytes)
# Skew : -0.0
# Email UL (Bytes)
# Skew : 0.01
# Youtube DL (Bytes)
# Skew : 0.0
# Youtube UL (Bytes)
# Skew : -0.0
# Netflix DL (Bytes)
# Skew : -0.0
# Netflix UL (Bytes)
# Skew : -0.0
# Gaming DL (Bytes)
# Skew : -0.0
# Gaming UL (Bytes)
# Skew : -0.0
# Other DL (Bytes)
# Skew : 0.0
# Other UL (Bytes)
# Skew : 0.0
# Total UL (Bytes)
# Skew : -0.0
# Total DL (Bytes)
# Skew : -0.0

# %%
# List of application UL variables
application_vars = ['Social Media UL (Bytes)', 'Google UL (Bytes)', 'Email UL (Bytes)', 'Youtube UL (Bytes)',
                       'Netflix UL (Bytes)', 'Gaming UL (Bytes)', 'Other UL (Bytes)','Social Media DL (Bytes)', 'Google DL (Bytes)', 'Email DL (Bytes)', 'Youtube DL (Bytes)',
                       'Netflix DL (Bytes)', 'Gaming DL (Bytes)', 'Other DL (Bytes)']

dfa['DL+UL (Bytes)']=dfa['Total UL (Bytes)']+dfa['Total DL (Bytes)']
# Iterate over each application variable and create pair plot with Total DL+UL data
for var in application_vars:
    subset = dfa[[var, 'DL+UL (Bytes)']]
    plt.figure(figsize=(13, 17))
    sns.pairplot(subset)
    plt.title(f'Pair Plot for {var} with Total UL')
    plt.show()

# %%
#segment the users into top five decile classes based on the total duration for all sessions and compute the total data DL+UL) per decile class
dfa['Total Duration'] = dfa['Dur. (ms)'] + dfa['Dur. (ms).1'] + dfa['Activity Duration DL (ms)'] + dfa['Activity Duration UL (ms)']

# Sort the users based on the total duration in descending order
sorted_dfa = dfa.sort_values('Total Duration', ascending=False)

# Divide the sorted users into five equal-sized deciles
decile_size = len(sorted_dfa) // 5

sorted_dfa['Decile Class'] = pd.qcut(sorted_dfa.index, 5, labels=False)
sorted_dfa['Decile Class'] = sorted_dfa['Decile Class'].apply(lambda x: x + 1)

# Compute the total data (DL+UL) per decile class
decile_data = sorted_dfa.groupby('Decile Class')[['DL+UL (Bytes)']].sum()

# Display the total data per decile class
print(decile_data)
# Out:
#               DL+UL (Bytes)
# Decile Class
# 1              1.486599e+13
# 2              1.486639e+13
# 3              1.490741e+13
# 4              1.488733e+13
# 5              1.483758e+13

# %%
#compute a correlation matrix for the following variables
# Column names from the dataset information
data_list = ['Social Media UL (Bytes)', 'Social Media DL (Bytes)',
             'Google UL (Bytes)', 'Google DL (Bytes)',
             'Email UL (Bytes)', 'Email DL (Bytes)',
             'Youtube UL (Bytes)', 'Youtube DL (Bytes)',
             'Netflix UL (Bytes)', 'Netflix DL (Bytes)',
             'Gaming UL (Bytes)', 'Gaming DL (Bytes)',
             'Other UL (Bytes)', 'Other DL (Bytes)']

# Create a subset of the data with the selected columns
subset = dfa[data_list]

# Compute the correlation matrix
correlation_matrix = subset.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                          Social Media UL (Bytes)  Social Media DL (Bytes)  \
# Social Media UL (Bytes)                 1.000000                -0.000555
# Social Media DL (Bytes)                -0.000555                 1.000000
# Google UL (Bytes)                       0.001085                 0.000186
# Google DL (Bytes)                       0.003542                -0.001954
# Email UL (Bytes)                       -0.001427                -0.002518
# Email DL (Bytes)                        0.004823                 0.004745
# Youtube UL (Bytes)                     -0.002368                 0.002345
# Youtube DL (Bytes)                     -0.001786                -0.001389
# Netflix UL (Bytes)                     -0.002493                 0.003457
# Netflix DL (Bytes)                     -0.000772                -0.001817
# Gaming UL (Bytes)                       0.000844                 0.003095
# Gaming DL (Bytes)                       0.000210                 0.001018
# Other UL (Bytes)                        0.000971                 0.000610
# Other DL (Bytes)                       -0.003850                 0.006126
#
#                          Google UL (Bytes)  Google DL (Bytes)  \
# Social Media UL (Bytes)           0.001085           0.003542
# Social Media DL (Bytes)           0.000186          -0.001954
# Google UL (Bytes)                 1.000000          -0.000103
# Google DL (Bytes)                -0.000103           1.000000
# Email UL (Bytes)                 -0.002050           0.000742
# Email DL (Bytes)                 -0.001157          -0.000039
# Youtube UL (Bytes)                0.001670           0.000638
# Youtube DL (Bytes)                0.001122           0.001760
# Netflix UL (Bytes)               -0.004073          -0.001569
# Netflix DL (Bytes)               -0.001288           0.000548
# Gaming UL (Bytes)                -0.002516          -0.001429
# Gaming DL (Bytes)                 0.001140          -0.001421
# Other UL (Bytes)                 -0.002219          -0.000882
# Other DL (Bytes)                  0.002097          -0.002557
#
#                          Email UL (Bytes)  Email DL (Bytes)  \
# Social Media UL (Bytes)         -0.001427          0.004823
# Social Media DL (Bytes)         -0.002518          0.004745
# Google UL (Bytes)               -0.002050         -0.001157
# Google DL (Bytes)                0.000742         -0.000039
# Email UL (Bytes)                 1.000000          0.002553
# Email DL (Bytes)                 0.002553          1.000000
# Youtube UL (Bytes)              -0.006834         -0.004305
# Youtube DL (Bytes)              -0.000320          0.001679
# Netflix UL (Bytes)               0.000532         -0.000016
# Netflix DL (Bytes)              -0.000011          0.001351
# Gaming UL (Bytes)                0.005000         -0.004335
# Gaming DL (Bytes)               -0.002519          0.000050
# Other UL (Bytes)                 0.000081          0.004675
# Other DL (Bytes)                -0.003805         -0.000444
#
#                          Youtube UL (Bytes)  Youtube DL (Bytes)  \
# Social Media UL (Bytes)           -0.002368           -0.001786
# Social Media DL (Bytes)            0.002345           -0.001389
# Google UL (Bytes)                  0.001670            0.001122
# Google DL (Bytes)                  0.000638            0.001760
# Email UL (Bytes)                  -0.006834           -0.000320
# Email DL (Bytes)                  -0.004305            0.001679
# Youtube UL (Bytes)                 1.000000            0.002433
# Youtube DL (Bytes)                 0.002433            1.000000
# Netflix UL (Bytes)                 0.002477            0.001746
# Netflix DL (Bytes)                 0.000423            0.001202
# Gaming UL (Bytes)                  0.000898           -0.001893
# Gaming DL (Bytes)                 -0.002382           -0.001861
# Other UL (Bytes)                  -0.001393           -0.004830
# Other DL (Bytes)                   0.002296            0.002042
#
#                          Netflix UL (Bytes)  Netflix DL (Bytes)  \
# Social Media UL (Bytes)           -0.002493           -0.000772
# Social Media DL (Bytes)            0.003457           -0.001817
# Google UL (Bytes)                 -0.004073           -0.001288
# Google DL (Bytes)                 -0.001569            0.000548
# Email UL (Bytes)                   0.000532           -0.000011
# Email DL (Bytes)                  -0.000016            0.001351
# Youtube UL (Bytes)                 0.002477            0.000423
# Youtube DL (Bytes)                 0.001746            0.001202
# Netflix UL (Bytes)                 1.000000            0.001065
# Netflix DL (Bytes)                 0.001065            1.000000
# Gaming UL (Bytes)                 -0.004015           -0.000633
# Gaming DL (Bytes)                 -0.001051           -0.003201
# Other UL (Bytes)                  -0.003447           -0.002588
# Other DL (Bytes)                  -0.006691           -0.006000
#
#                          Gaming UL (Bytes)  Gaming DL (Bytes)  \
# Social Media UL (Bytes)           0.000844           0.000210
# Social Media DL (Bytes)           0.003095           0.001018
# Google UL (Bytes)                -0.002516           0.001140
# Google DL (Bytes)                -0.001429          -0.001421
# Email UL (Bytes)                  0.005000          -0.002519
# Email DL (Bytes)                 -0.004335           0.000050
# Youtube UL (Bytes)                0.000898          -0.002382
# Youtube DL (Bytes)               -0.001893          -0.001861
# Netflix UL (Bytes)               -0.004015          -0.001051
# Netflix DL (Bytes)               -0.000633          -0.003201
# Gaming UL (Bytes)                 1.000000           0.001162
# Gaming DL (Bytes)                 0.001162           1.000000
# Other UL (Bytes)                 -0.006011          -0.001131
# Other DL (Bytes)                 -0.002381          -0.002591
#
#                          Other UL (Bytes)  Other DL (Bytes)
# Social Media UL (Bytes)          0.000971         -0.003850
# Social Media DL (Bytes)          0.000610          0.006126
# Google UL (Bytes)               -0.002219          0.002097
# Google DL (Bytes)               -0.000882         -0.002557
# Email UL (Bytes)                 0.000081         -0.003805
# Email DL (Bytes)                 0.004675         -0.000444
# Youtube UL (Bytes)              -0.001393          0.002296
# Youtube DL (Bytes)              -0.004830          0.002042
# Netflix UL (Bytes)              -0.003447         -0.006691
# Netflix DL (Bytes)              -0.002588         -0.006000
# Gaming UL (Bytes)               -0.006011         -0.002381
# Gaming DL (Bytes)               -0.001131         -0.002591
# Other UL (Bytes)                 1.000000          0.003421
# Other DL (Bytes)                 0.003421          1.000000

# %%
#Dimensionality Reduction

# %%
dfa_clean=dfa[['Bearer Id','Start']]
dfa_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Bearer Id  149010 non-null  float64
#  1   Start      150000 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 2.3+ MB

# %%
#export the clean data to postgres
dfa_clean.to_sql('clean_data',alchemyConn)
# Out:
# 1
